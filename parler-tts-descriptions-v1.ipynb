# %% [markdown]
# ### Clone Repo

# %%
# !git clone https://github.com/huggingface/dataspeech.git
# Out:
# Cloning into 'dataspeech'...
# remote: Enumerating objects: 650, done.
# remote: Counting objects: 100% (221/221), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 650 (delta 138), reused 131 (delta 131), pack-reused 429 (from 1)
# Receiving objects: 100% (650/650), 158.78 KiB | 8.82 MiB/s, done.
# Resolving deltas: 100% (395/395), done.

# %% [markdown]
# ### Install Requirements

# %%
# %cd dataspeech
# !pip install -r requirements.txt -q
# Out:
# /kaggle/working/dataspeech
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dataproc-jupyter-plugin 0.1.79 requires pydantic~=1.10.0, but you have pydantic 2.8.2 which is incompatible.
# ydata-profiling 4.10.0 requires scipy<1.14,>=1.4.1, but you have scipy 1.14.1 which is incompatible.

# %% [markdown]
# ### Prepare Huggingface Access

# %%
from huggingface_hub import HfApi, HfFolder
import os

# %%
os.environ['HF_TOKEN'] = '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'

# %%
hf_api = HfApi()
HfFolder.save_token(os.environ['HF_TOKEN'])

# %%
user_info = hf_api.whoami()
print(f"Logged in as: {user_info['name']}")
# Out:
# Logged in as: Amadeus99

# %% [markdown]
# ### Annotate Dataset

# %%
# !python ./scripts/run_prompt_creation.py \
  --speaker_name "Justin" \
  --is_single_speaker \
  --is_new_speaker_prompt \
  --dataset_name "Amadeus99/dataset-final-project-v2-processed" \
  --output_dir "./tmp_justin" \
  --dataset_config_name "default" \
  --model_name_or_path "google/gemma-2-2b-it" \
  --per_device_eval_batch_size 5 \
  --attn_implementation "sdpa" \
  --dataloader_num_workers 2 \
  --push_to_hub \
  --hub_dataset_id "dataset-final-project-v2-descriptions" \
  --preprocessing_num_workers 2
# Out:
# README.md: 100%|███████████████████████████████| 905/905 [00:00<00:00, 6.05MB/s]
# train-00000-of-00001.parquet: 100%|████████| 2.30M/2.30M [00:00<00:00, 45.9MB/s]
# Setting num_proc from 2 back to 1 for the train split to disable multiprocessing as it only contains one shard.
# ...
# config.json: 100%|█████████████████████████████| 838/838 [00:00<00:00, 4.71MB/s]
# model.safetensors.index.json: 100%|████████| 24.2k/24.2k [00:00<00:00, 2.80MB/s]
# ...
# model-00001-of-00002.safetensors:   0%|             | 0.00/4.99G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|    | 10.5M/4.99G [00:00<01:59, 41.6MB/s]
# model-00001-of-00002.safetensors:   0%|    | 21.0M/4.99G [00:00<01:57, 42.3MB/s]
# model-00001-of-00002.safetensors:   1%|    | 31.5M/4.99G [00:00<01:55, 42.8MB/s]
# model-00001-of-00002.safetensors:   1%|    | 41.9M/4.99G [00:00<01:53, 43.5MB/s]
# model-00001-of-00002.safetensors:   1%|    | 52.4M/4.99G [00:01<01:54, 43.2MB/s]
# ...
